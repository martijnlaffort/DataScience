# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
penguins = sns.load_dataset('penguins')

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguinsCorr = penguins.corr()
penguinsCorr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_69a9f946_8193_11eb_b11c_a06adebfec98row0_col0,#T_69a9f946_8193_11eb_b11c_a06adebfec98row1_col1,#T_69a9f946_8193_11eb_b11c_a06adebfec98row2_col2,#T_69a9f946_8193_11eb_b11c_a06adebfec98row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_69a9f946_8193_11eb_b11c_a06adebfec98row0_col1,#T_69a9f946_8193_11eb_b11c_a06adebfec98row1_col0{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_69a9f946_8193_11eb_b11c_a06adebfec98row0_col2,#T_69a9f946_8193_11eb_b11c_a06adebfec98row2_col0{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_69a9f946_8193_11eb_b11c_a06adebfec98row0_col3,#T_69a9f946_8193_11eb_b11c_a06adebfec98row3_col0{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_69a9f946_8193_11eb_b11c_a06adebfec98row1_col2,#T_69a9f946_8193_11eb_b11c_a06adebfec98row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_69a9f946_8193_11eb_b11c_a06adebfec98row1_col3,#T_69a9f946_8193_11eb_b11c_a06adebfec98row3_col1{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_69a9f946_8193_11eb_b11c_a06adebfec98row2_col3,#T_69a9f946_8193_11eb_b11c_a06adebfec98row3_col2{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }</style><table id="T_69a9f946_8193_11eb_b11c_a06adebfec98" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >bill_length_mm</th>        <th class="col_heading level0 col1" >bill_depth_mm</th>        <th class="col_heading level0 col2" >flipper_length_mm</th>        <th class="col_heading level0 col3" >body_mass_g</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69a9f946_8193_11eb_b11c_a06adebfec98level0_row0" class="row_heading level0 row0" >bill_length_mm</th>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row0_col1" class="data row0 col1" >-0.24</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row0_col2" class="data row0 col2" >0.66</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row0_col3" class="data row0 col3" >0.60</td>
#             </tr>
#             <tr>
#                         <th id="T_69a9f946_8193_11eb_b11c_a06adebfec98level0_row1" class="row_heading level0 row1" >bill_depth_mm</th>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row1_col0" class="data row1 col0" >-0.24</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row1_col2" class="data row1 col2" >-0.58</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row1_col3" class="data row1 col3" >-0.47</td>
#             </tr>
#             <tr>
#                         <th id="T_69a9f946_8193_11eb_b11c_a06adebfec98level0_row2" class="row_heading level0 row2" >flipper_length_mm</th>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row2_col0" class="data row2 col0" >0.66</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row2_col1" class="data row2 col1" >-0.58</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row2_col3" class="data row2 col3" >0.87</td>
#             </tr>
#             <tr>
#                         <th id="T_69a9f946_8193_11eb_b11c_a06adebfec98level0_row3" class="row_heading level0 row3" >body_mass_g</th>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row3_col0" class="data row3 col0" >0.60</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row3_col1" class="data row3 col1" >-0.47</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row3_col2" class="data row3 col2" >0.87</td>
#                         <td id="T_69a9f946_8193_11eb_b11c_a06adebfec98row3_col3" class="data row3 col3" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
penguins.plot(kind='scatter', x='flipper_length_mm', y='body_mass_g')

plt.title('Meeste correlatie')
plt.xlabel('Flipper length in mm')
plt.ylabel('Body mass in grams')

plt.show()

# %% [markdown]
# Hier zie je veel correlatie

# %%
penguins.plot(kind='scatter', x='flipper_length_mm', y='bill_depth_mm')

plt.title('Matige correlatie')
plt.xlabel('Flipper length in mm')
plt.ylabel('Bill depth in mm')

plt.show()

# %% [markdown]
# Ik zie hier wat minder correlatie

# %%
penguins.plot(kind='scatter', x='bill_depth_mm', y='bill_length_mm')

plt.title('Geen correlatie')
plt.xlabel('Bill depth in mm')
plt.ylabel('Bill length in mm')

plt.show()

# %% [markdown]
# Hier zie ik nauwelijks correlatie
