# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# %%
spotify = pd.read_csv('data.csv', sep=',')

# %%
spotify.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
spotify.tail()
# Out:
#         acousticness                             artists  danceability  \
# 174384       0.00917  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385       0.79500                    ['Alessia Cara']         0.429
# 174386       0.80600                       ['Roger Fly']         0.671
# 174387       0.92000                    ['Taylor Swift']         0.462
# 174388       0.23900                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# 174384       147615   0.866         0  46LhBf6TvYjZU2SMvGZAbn
# 174385       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
# 174386       218147   0.589         0  48Qj61hOdYmUCFJbpQ29Ob
# 174387       244000   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP
# 174388       197710   0.460         0  57tgYkWQTNHVFEt6xDKKZj
#
#         instrumentalness  key  liveness  loudness  mode                name  \
# 174384           0.00006    6     0.178    -5.089     0             The One
# ...

# %% [markdown]
# Opdracht 10

# %%
filteredSpotify = spotify[['artists', 'danceability', 'energy']]

# %%
filteredCor = filteredSpotify.corr()
filteredCor.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_e3deefb9_7b49_11eb_8ee3_a06adebfec98row0_col0,#T_e3deefb9_7b49_11eb_8ee3_a06adebfec98row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e3deefb9_7b49_11eb_8ee3_a06adebfec98row0_col1,#T_e3deefb9_7b49_11eb_8ee3_a06adebfec98row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_e3deefb9_7b49_11eb_8ee3_a06adebfec98" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >danceability</th>        <th class="col_heading level0 col1" >energy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3deefb9_7b49_11eb_8ee3_a06adebfec98level0_row0" class="row_heading level0 row0" >danceability</th>
#                         <td id="T_e3deefb9_7b49_11eb_8ee3_a06adebfec98row0_col0" class="data row0 col0" >1.00</td>
# ...

# %%
filteredSpotify.plot(kind='scatter', x='danceability', y='energy', s=0.8)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='energy'>

# %%
live = spotify[['danceability', 'liveness']]

# %%
live.corr()
# Out:
#               danceability  liveness
# danceability      1.000000 -0.110033
# liveness         -0.110033  1.000000

# %%
popular = spotify[['popularity', 'liveness', 'energy', 'acousticness']]

# %%
popcorr = popular.corr()

# %%
popcorr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_e4132c17_7b49_11eb_9fcc_a06adebfec98row0_col0,#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row1_col1,#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row2_col2,#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row0_col1,#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row1_col0{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row0_col2,#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row2_col0{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row0_col3,#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row3_col0{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row1_col2,#T_e4132c17_7b49_11eb_9fcc_a06adebfec98row2_col1{
# ...

# %%
energy = spotify['energy']

# %%
dance = spotify['danceability']

# %%
xy = np.vstack([dance, energy])

# %%
spotifyCor = spotify.corr()

# %%
spotifyCor.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_e42d31fb_7b49_11eb_99a6_a06adebfec98row0_col0,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row1_col1,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row2_col2,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row3_col3,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row4_col4,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row5_col5,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row6_col6,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row7_col7,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row8_col8,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row9_col9,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row10_col10,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row11_col11,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row12_col12,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row13_col13,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row0_col1,#T_e42d31fb_7b49_11eb_99a6_a06adebfec98row1_col0{
# ...

# %%
spotify.plot(kind='scatter', x='loudness', y='energy', s=0.8)
# Out:
# <AxesSubplot:xlabel='loudness', ylabel='energy'>

# %%
spotify.plot(kind='scatter', x='acousticness', y='energy', s=0.8)
# Out:
# <AxesSubplot:xlabel='acousticness', ylabel='energy'>

# %%
spotify.plot(kind='scatter', x='tempo', y='danceability', s=0.8)
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='danceability'>

# %% [markdown]
# opdracht 12

# %%
spotify.groupby('tempo').mean()
# Out:
#          acousticness  danceability    duration_ms    energy  explicit  \
# tempo
# 0.000        0.602378         0.000  121595.561983  0.241229  0.024793
# 30.946       0.855000         0.422  173960.000000  0.158000  0.000000
# 31.988       0.927000         0.189  197307.000000  0.160000  0.000000
# 32.571       0.461000         0.831  126498.000000  0.208000  0.000000
# 32.800       0.419000         0.702   92775.000000  0.290000  0.000000
# ...               ...           ...            ...       ...       ...
# 224.437      0.084100         0.157  229840.000000  0.500000  0.000000
# 236.799      0.261000         0.332  373970.000000  0.423000  0.000000
# 238.895      0.617000         0.429  194733.000000  0.225000  0.000000
# 243.372      0.198000         0.466  147200.000000  0.188000  0.000000
# 243.507      0.497000         0.535  277221.000000  0.380000  0.000000
#
#          instrumentalness        key  liveness   loudness     mode  \
# tempo
# ...

# %%
spotify.groupby('artists').mean()
# Out:
#                                                     acousticness  \
# artists
# ["'In The Heights' Original Broadway Company", ...      0.848000
# ["'Til Tuesday"]                                        0.105556
# ["100 First Songs' Participants"]                       0.682000
# ["AKA ChaP in 00'S"]                                    0.122000
# ["Adolescent's Orquesta"]                               0.377250
# ...                                                          ...
# ['黑豹']                                                  0.381000
# ['龔詩嘉']                                                 0.134000
# ['김수철']                                                 0.509000
# ['김효근', 'Quinever 퀸에버']                                 0.939000
# ['조정현']                                                 0.568000
#
#                                                     danceability  duration_ms  \
# artists
# ["'In The Heights' Original Broadway Company", ...      0.397000    244067.00
# ...

# %%
spotify.groupby('release_date').mean()
# Out:
#               acousticness  danceability    duration_ms    energy  explicit  \
# release_date
# 1920              0.882046      0.444122  296624.007692  0.242845  0.130769
# 1920-01-01        0.620923      0.541500  261077.125000  0.543177  0.093750
# 1920-01-03        0.092442      0.731667  240988.916667  0.327750  0.000000
# 1920-01-04        0.305842      0.471683   96782.024390  0.546739  0.000000
# 1920-01-05        0.643000      0.852000  150200.000000  0.517000  0.000000
# ...                    ...           ...            ...       ...       ...
# 2021-01-19        0.465351      0.617682  228790.909091  0.404863  0.000000
# 2021-01-20        0.142061      0.638442  298440.465116  0.683749  0.069767
# 2021-01-21        0.404379      0.547526  229395.526316  0.508789  0.526316
# 2021-01-22        0.192065      0.696188  209937.111446  0.736910  0.084337
# 2021-01-23        0.778330      0.529270  223553.270270  0.121611  0.000000
#
# ...

# %%
sns.barplot(y="energy", x="release_date", data=spotify)
# Out:
# <AxesSubplot:xlabel='release_date', ylabel='energy'>

# %%
current_decade = spotify[spotify["year"] > 2009]

# %%
sns.barplot(y="energy", x="year", data=current_decade)
# Out:
# <AxesSubplot:xlabel='year', ylabel='energy'>

# %%
sns.barplot(y="popularity", x="year", data=current_decade)
# Out:
# <AxesSubplot:xlabel='year', ylabel='popularity'>

# %%
sns.barplot(y="danceability", x="year", data=current_decade)
# Out:
# <AxesSubplot:xlabel='year', ylabel='danceability'>

# %%
first_decade = spotify[spotify["year"] < 1930]

# %%
sns.barplot(y="energy", x="year", data=first_decade)
# Out:
# <AxesSubplot:xlabel='year', ylabel='energy'>

# %%
sns.barplot(y="popularity", x="year", data=first_decade)
# Out:
# <AxesSubplot:xlabel='year', ylabel='popularity'>

# %%
sns.barplot(y="danceability", x="year", data=first_decade)
# Out:
# <AxesSubplot:xlabel='year', ylabel='danceability'>
